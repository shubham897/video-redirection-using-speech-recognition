# %%
import speech_recognition as sr
import timeit
r = sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("Say what you want to search in the video");
    audio = r.listen(source, timeout=1, phrase_time_limit = 3)
try:
    said = r.recognize_google(audio)
    print("You said: " + r.recognize_google(audio))
except:
    pass
# Out:
# Say what you want to search in the video
# You said: breakfast

# %%
from pydub import AudioSegment 
import speech_recognition as sr

r = sr.Recognizer()
  
# Input audio file to be sliced 
audio = AudioSegment.from_wav("YouTube.wav") 
  
''' 
Step #1 - Slicing the audio file into smaller chunks. 
'''
# Length of the audiofile in milliseconds 
n = len(audio) 
  
# Variable to count the number of sliced chunks 
counter = 1
  
# Text file to write the recognized audio 
fh = open("recognized.txt", "w+") 
  
# Interval length at which to slice the audio file. 
# If length is 22 seconds, and interval is 5 seconds, 
# The chunks created will be: 
# chunk1 : 0 - 5 seconds 
# chunk2 : 5 - 10 seconds 
# chunk3 : 10 - 15 seconds 
# chunk4 : 15 - 20 seconds 
# chunk5 : 20 - 22 seconds 
interval = 5 * 1000
  
# Length of audio to overlap.  
# If length is 22 seconds, and interval is 5 seconds, 
# With overlap as 1.5 seconds, 
# The chunks created will be: 
# chunk1 : 0 - 5 seconds 
# chunk2 : 3.5 - 8.5 seconds 
# chunk3 : 7 - 12 seconds 
# chunk4 : 10.5 - 15.5 seconds 
# chunk5 : 14 - 19.5 seconds 
# chunk6 : 18 - 22 seconds 
overlap = 1.5 * 1000
  
# Initialize start and end seconds to 0 
start = 0
end = 0
  
# Flag to keep track of end of file. 
# When audio reaches its end, flag is set to 1 and we break 
flag = 0
  
# Iterate from 0 to end of the file, 
# with increment = interval 
for i in range(0, 2 * n, interval): 
      
    # During first iteration, 
    # start is 0, end is the interval 
    if i == 0: 
        start = 0
        end = interval 
  
    # All other iterations, 
    # start is the previous end - overlap 
    # end becomes end + interval 
    else: 
        start = end - overlap 
        end = start + interval  
  
    # When end becomes greater than the file length, 
    # end is set to the file length 
    # flag is set to 1 to indicate break. 
    if end >= n: 
        end = n 
        flag = 1
  
    # Storing audio file from the defined start to end 
    chunk = audio[start:end] 
  
    # Filename / Path to store the sliced audio 
    filename = 'chunk'+str(counter)+'.wav'
  
    # Store the sliced audio file to the defined path 
    chunk.export(filename, format ="wav") 
    # Print information about the current chunk 
    print("Processing chunk "+str(counter)+". Start = "
                        +str(start)+" end = "+str(end)) 
  
    # Increment counter for the next chunk 
    counter = counter + 1
      
    # Slicing of the audio file is done. 
    # Skip the below steps if there is some other usage 
    # for the sliced audio files.
# Out:
# Processing chunk 1. Start = 0 end = 5000
# Processing chunk 2. Start = 3500.0 end = 8500.0
# Processing chunk 3. Start = 7000.0 end = 12000.0
# Processing chunk 4. Start = 10500.0 end = 15500.0
# Processing chunk 5. Start = 14000.0 end = 19000.0
# Processing chunk 6. Start = 17500.0 end = 22500.0
# Processing chunk 7. Start = 21000.0 end = 26000.0
# Processing chunk 8. Start = 24500.0 end = 29500.0
# Processing chunk 9. Start = 28000.0 end = 33000.0
# Processing chunk 10. Start = 31500.0 end = 36500.0
# Processing chunk 11. Start = 35000.0 end = 40000.0
# Processing chunk 12. Start = 38500.0 end = 43500.0
# Processing chunk 13. Start = 42000.0 end = 47000.0
# Processing chunk 14. Start = 45500.0 end = 50500.0
# Processing chunk 15. Start = 49000.0 end = 54000.0
# Processing chunk 16. Start = 52500.0 end = 57500.0
# Processing chunk 17. Start = 56000.0 end = 61000.0
# Processing chunk 18. Start = 59500.0 end = 64500.0
# Processing chunk 19. Start = 63000.0 end = 68000.0
# Processing chunk 20. Start = 66500.0 end = 71500.0
# Processing chunk 21. Start = 70000.0 end = 75000.0
# Processing chunk 22. Start = 73500.0 end = 78500.0
# Processing chunk 23. Start = 77000.0 end = 82000.0
# Processing chunk 24. Start = 80500.0 end = 85500.0
# Processing chunk 25. Start = 84000.0 end = 89000.0
# Processing chunk 26. Start = 87500.0 end = 92500.0
# Processing chunk 27. Start = 91000.0 end = 96000.0
# Processing chunk 28. Start = 94500.0 end = 99500.0
# Processing chunk 29. Start = 98000.0 end = 103000.0
# Processing chunk 30. Start = 101500.0 end = 106500.0
# Processing chunk 31. Start = 105000.0 end = 110000.0
# Processing chunk 32. Start = 108500.0 end = 113500.0
# Processing chunk 33. Start = 112000.0 end = 117000.0
# Processing chunk 34. Start = 115500.0 end = 120500.0
# Processing chunk 35. Start = 119000.0 end = 124000.0
# Processing chunk 36. Start = 122500.0 end = 127500.0
# Processing chunk 37. Start = 126000.0 end = 131000.0
# Processing chunk 38. Start = 129500.0 end = 134500.0
# Processing chunk 39. Start = 133000.0 end = 138000.0
# Processing chunk 40. Start = 136500.0 end = 141500.0
# Processing chunk 41. Start = 140000.0 end = 145000.0
# Processing chunk 42. Start = 143500.0 end = 148500.0
# Processing chunk 43. Start = 147000.0 end = 152000.0
# Processing chunk 44. Start = 150500.0 end = 155500.0
# Processing chunk 45. Start = 154000.0 end = 159000.0
# Processing chunk 46. Start = 157500.0 end = 162500.0
# Processing chunk 47. Start = 161000.0 end = 166000.0
# Processing chunk 48. Start = 164500.0 end = 169500.0
# Processing chunk 49. Start = 168000.0 end = 173000.0
# Processing chunk 50. Start = 171500.0 end = 176500.0
# Processing chunk 51. Start = 175000.0 end = 180000.0
# Processing chunk 52. Start = 178500.0 end = 183500.0
# Processing chunk 53. Start = 182000.0 end = 187000.0
# Processing chunk 54. Start = 185500.0 end = 190500.0
# Processing chunk 55. Start = 189000.0 end = 194000.0
# Processing chunk 56. Start = 192500.0 end = 197500.0
# Processing chunk 57. Start = 196000.0 end = 201000.0
# Processing chunk 58. Start = 199500.0 end = 204500.0
# Processing chunk 59. Start = 203000.0 end = 208000.0
# Processing chunk 60. Start = 206500.0 end = 211500.0
# Processing chunk 61. Start = 210000.0 end = 215000.0
# Processing chunk 62. Start = 213500.0 end = 218500.0
# Processing chunk 63. Start = 217000.0 end = 222000.0
# Processing chunk 64. Start = 220500.0 end = 225500.0
# Processing chunk 65. Start = 224000.0 end = 225721
# Processing chunk 66. Start = 224221.0 end = 225721
# Processing chunk 67. Start = 224221.0 end = 225721
# Processing chunk 68. Start = 224221.0 end = 225721
# Processing chunk 69. Start = 224221.0 end = 225721
# Processing chunk 70. Start = 224221.0 end = 225721
# Processing chunk 71. Start = 224221.0 end = 225721
# Processing chunk 72. Start = 224221.0 end = 225721
# Processing chunk 73. Start = 224221.0 end = 225721
# Processing chunk 74. Start = 224221.0 end = 225721
# Processing chunk 75. Start = 224221.0 end = 225721
# Processing chunk 76. Start = 224221.0 end = 225721
# Processing chunk 77. Start = 224221.0 end = 225721
# Processing chunk 78. Start = 224221.0 end = 225721
# Processing chunk 79. Start = 224221.0 end = 225721
# Processing chunk 80. Start = 224221.0 end = 225721
# Processing chunk 81. Start = 224221.0 end = 225721
# Processing chunk 82. Start = 224221.0 end = 225721
# Processing chunk 83. Start = 224221.0 end = 225721
# Processing chunk 84. Start = 224221.0 end = 225721
# Processing chunk 85. Start = 224221.0 end = 225721
# Processing chunk 86. Start = 224221.0 end = 225721
# Processing chunk 87. Start = 224221.0 end = 225721
# Processing chunk 88. Start = 224221.0 end = 225721
# Processing chunk 89. Start = 224221.0 end = 225721
# Processing chunk 90. Start = 224221.0 end = 225721
# Processing chunk 91. Start = 224221.0 end = 225721

# %%
import time
start = 0

end = 0
flag = 0
interval = 5 * 1000
counter=1
for i in range(0, 2 * n, interval):
    if i == 0: 
        start = 0
        end = interval 
    else: 
        start = end - overlap 
        end = start + interval
    if end >= n: 
        end = n 
        flag = 1
    print(end)
    if flag != 1:
        filename = 'chunk'+str(counter)+'.wav'
        with sr.WavFile(filename) as source:              # use "test.wav" as the audio source
                audio = r.record(source)
                try:
                    print("Transcription: " + r.recognize_google(audio)) 
                    a = r.recognize_google(audio).split()
                    if "said" in a:
                        print("True") # recognize speech using Google Speech Recognition
                except LookupError:                                 # speech is unintelligible
                    print("Could not understand audio")
    counter = counter + 1
# Out:
# 5000
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# <ipython-input-48-45f9b4008bf8> in <module>
#      22                 audio = r.record(source)
#      23                 try:
# ---> 24                     print("Transcription: " + r.recognize_google(audio))
#      25                     a = r.recognize_google(audio).split()
#      26                     if "said" in a:
#
# ~\Anaconda3\lib\site-packages\speech_recognition\__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     856         # return results
#     857         if show_all: return actual_result
# --> 858         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     859
#     860         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %%
print(n)
# Out:
# 225721
